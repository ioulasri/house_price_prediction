# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(["median_house_value"], axis=1)

# %%
y = data["median_house_value"]

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3736     -118.40     34.18                32.0       3724.0           899.0
# 17771    -121.84     37.37                15.0       3315.0          1042.0
# 18715    -122.40     40.57                23.0       1321.0           259.0
# 9169     -118.61     34.59                 5.0       4028.0           896.0
# 16168    -122.51     37.78                47.0       2496.0           494.0
# ...          ...       ...                 ...          ...             ...
# 20327    -119.06     34.24                21.0       7436.0           984.0
# 12544    -121.49     38.55                51.0       4280.0           632.0
# 20084    -120.27     38.02                13.0       3839.0           715.0
# 13429    -117.45     34.10                 6.0       5571.0          1316.0
# 7500     -118.25     33.92                44.0       1137.0           235.0
#
#        population  households  median_income ocean_proximity  \
# 3736       1912.0       791.0         3.5711       <1H OCEAN
# 17771      2749.0      1059.0         2.3199       <1H OCEAN
# 18715       749.0       222.0         1.6550          INLAND
# 9169       2062.0       826.0         4.0579          INLAND
# 16168      1201.0       454.0         4.0353        NEAR BAY
# ...           ...         ...            ...             ...
# 20327      2982.0       988.0         7.6775       <1H OCEAN
# 12544      1486.0       621.0         5.0359          INLAND
# 20084      1486.0       532.0         3.1875          INLAND
# 13429      4048.0      1154.0         2.0308          INLAND
# 7500        747.0       225.0         2.0000       <1H OCEAN
#
#        median_house_value
# 3736             312700.0
# 17771            140100.0
# 18715             90100.0
# 9169             167100.0
# 16168            342200.0
# ...                   ...
# 20327            391200.0
# 12544            224100.0
# 20084             99800.0
# 13429             91100.0
# 7500              92600.0
#
# [15324 rows x 10 columns]

# %%
train_data.hist(figsize=(20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
train_data.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924482           -0.114625     0.047820
# latitude            -0.924482  1.000000            0.018444    -0.040553
# housing_median_age  -0.114625  0.018444            1.000000    -0.366019
# total_rooms          0.047820 -0.040553           -0.366019     1.000000
# total_bedrooms       0.073498 -0.071914           -0.324567     0.929304
# population           0.105298 -0.114338           -0.301181     0.855778
# households           0.060650 -0.076781           -0.307644     0.918637
# median_income       -0.019425 -0.076190           -0.125243     0.202286
# median_house_value  -0.049092 -0.141442            0.097784     0.136728
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.073498    0.105298    0.060650      -0.019425
# latitude                 -0.071914   -0.114338   -0.076781      -0.076190
# housing_median_age       -0.324567   -0.301181   -0.307644      -0.125243
# total_rooms               0.929304    0.855778    0.918637       0.202286
# total_bedrooms            1.000000    0.876466    0.980017      -0.005435
# population                0.876466    1.000000    0.905476       0.007997
# households                0.980017    0.905476    1.000000       0.016040
# median_income            -0.005435    0.007997    0.016040       1.000000
# median_house_value        0.052175   -0.022527    0.067184       0.688450
#
#                     median_house_value
# longitude                    -0.049092
# latitude                     -0.141442
# housing_median_age            0.097784
# total_rooms                   0.136728
# total_bedrooms                0.052175
# population                   -0.022527
# households                    0.067184
# median_income                 0.688450
# median_house_value            1.000000

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
train_data.hist(figsize=(20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
train_data["total_rooms"] = np.log(train_data["total_rooms"] + 1)
train_data["total_bedrooms"] = np.log(train_data["total_bedrooms"] + 1)
train_data["households"] = np.log(train_data["households"] + 1)
train_data["population"] = np.log(train_data["population"] + 1)

# %%
train_data.hist(figsize=(20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6863
# INLAND        4810
# NEAR OCEAN    1950
# NEAR BAY      1697
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity, dtype=int)).drop(["ocean_proximity"], axis=1)

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"] = train_data["total_bedrooms"] / train_data["total_rooms"]
train_data["household_rooms"] = train_data["total_rooms"] / train_data["households"]

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, y_train = train_data.drop(["median_house_value"], axis=1), train_data["median_house_value"]
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16515    -121.22     37.80                37.0       1038.0           222.0
# 19500    -121.03     37.67                24.0       2162.0           459.0
# 14975    -116.99     32.70                15.0       3660.0           622.0
# 3788     -118.37     34.17                42.0        600.0           171.0
# 10991    -117.81     33.73                19.0       4022.0           975.0
# ...          ...       ...                 ...          ...             ...
# 7012     -118.07     33.96                30.0        928.0           230.0
# 20017    -119.06     36.09                11.0       2572.0           454.0
# 17950    -121.96     37.34                18.0       4438.0           939.0
# 6387     -118.07     34.16                35.0       3585.0           671.0
# 15619    -122.42     37.80                50.0       2494.0           731.0
#
#        population  households  median_income ocean_proximity  \
# 16515       521.0       211.0         2.1250          INLAND
# 19500      1468.0       441.0         3.1857          INLAND
# 14975      2629.0       612.0         4.0444      NEAR OCEAN
# 3788        377.0       181.0         2.4107       <1H OCEAN
# 10991      2334.0       954.0         3.0305       <1H OCEAN
# ...           ...         ...            ...             ...
# 7012        913.0       214.0         2.6991       <1H OCEAN
# 20017      1402.0       415.0         3.6786          INLAND
# 17950      1901.0       895.0         5.3873       <1H OCEAN
# 6387       1401.0       623.0         4.1250          INLAND
# 15619       958.0       712.0         3.2356        NEAR BAY
#
#        median_house_value
# 16515             91900.0
# 19500             98300.0
# 14975            150100.0
# 3788             184400.0
# 10991            140600.0
# ...                   ...
# 7012             147100.0
# 20017             72900.0
# 17950            288300.0
# 6387             330000.0
# 15619            500001.0
#
# [5109 rows x 10 columns]

# %%
test_data["total_rooms"] = np.log(test_data["total_rooms"] + 1)
test_data["total_bedrooms"] = np.log(test_data["total_bedrooms"] + 1)
test_data["households"] = np.log(test_data["households"] + 1)
test_data["population"] = np.log(test_data["population"] + 1)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16515    -121.22     37.80                37.0     6.946014        5.407172
# 19500    -121.03     37.67                24.0     7.679251        6.131226
# 14975    -116.99     32.70                15.0     8.205492        6.434547
# 3788     -118.37     34.17                42.0     6.398595        5.147494
# 10991    -117.81     33.73                19.0     8.299783        6.883463
# ...          ...       ...                 ...          ...             ...
# 7012     -118.07     33.96                30.0     6.834109        5.442418
# 20017    -119.06     36.09                11.0     7.852828        6.120297
# 17950    -121.96     37.34                18.0     8.398184        6.845880
# 6387     -118.07     34.16                35.0     8.184793        6.510258
# 15619    -122.42     37.80                50.0     7.822044        6.595781
#
#        population  households  median_income ocean_proximity  \
# 16515    6.257668    5.356586         2.1250          INLAND
# 19500    7.292337    6.091310         3.1857          INLAND
# 14975    7.874739    6.418365         4.0444      NEAR OCEAN
# 3788     5.934894    5.204007         2.4107       <1H OCEAN
# 10991    7.755767    6.861711         3.0305       <1H OCEAN
# ...           ...         ...            ...             ...
# 7012     6.817831    5.370638         2.6991       <1H OCEAN
# 20017    7.246368    6.030685         3.6786          INLAND
# 17950    7.550661    6.797940         5.3873       <1H OCEAN
# 6387     7.245655    6.436150         4.1250          INLAND
# 15619    6.865891    6.569481         3.2356        NEAR BAY
#
#        median_house_value
# 16515             91900.0
# 19500             98300.0
# 14975            150100.0
# 3788             184400.0
# 10991            140600.0
# ...                   ...
# 7012             147100.0
# 20017             72900.0
# 17950            288300.0
# 6387             330000.0
# 15619            500001.0
#
# [5109 rows x 10 columns]

# %%
test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity, dtype=int)).drop(["ocean_proximity"], axis=1)

# %%
test_data["bedroom_ratio"] = test_data["total_bedrooms"] / test_data["total_rooms"]
test_data["household_rooms"] = test_data["total_rooms"] / test_data["households"]

# %%
X_test, y_test = test_data.drop(["median_house_value"], axis=1), test_data["median_house_value"]
X_test_s = scaler.transform(X_test)

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3736     -118.40     34.18                32.0     8.222822        6.802395
# 17771    -121.84     37.37                15.0     8.106515        6.949856
# 18715    -122.40     40.57                23.0     7.186901        5.560682
# 9169     -118.61     34.59                 5.0     8.301273        6.799056
# 16168    -122.51     37.78                47.0     7.822845        6.204558
# ...          ...       ...                 ...          ...             ...
# 20327    -119.06     34.24                21.0     8.914223        6.892642
# 12544    -121.49     38.55                51.0     8.361942        6.450470
# 20084    -120.27     38.02                13.0     8.253228        6.573680
# 13429    -117.45     34.10                 6.0     8.625509        7.183112
# 7500     -118.25     33.92                44.0     7.037028        5.463832
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 3736     7.556428    6.674561         3.5711          1       0       0
# 17771    7.919356    6.966024         2.3199          1       0       0
# 18715    6.620073    5.407172         1.6550          0       1       0
# 9169     7.631917    6.717805         4.0579          0       1       0
# 16168    7.091742    6.120297         4.0353          0       0       0
# ...           ...         ...            ...        ...     ...     ...
# 20327    8.000685    6.896694         7.6775          1       0       0
# 12544    7.304516    6.432940         5.0359          0       1       0
# 20084    7.304516    6.278521         3.1875          0       1       0
# 13429    8.306225    7.051856         2.0308          0       1       0
# 7500     6.617403    5.420535         2.0000          1       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 3736          0           0       0.827258         1.231964
# 17771         0           0       0.857317         1.163722
# 18715         0           0       0.773725         1.329142
# 9169          0           0       0.819038         1.235712
# 16168         1           0       0.793133         1.278181
# ...         ...         ...            ...              ...
# 20327         0           0       0.773218         1.292536
# 12544         0           0       0.771408         1.299863
# 20084         0           0       0.796498         1.314518
# 13429         0           0       0.832775         1.223155
# 7500          0           0       0.776440         1.298216
#
# [15324 rows x 15 columns]

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16515    -121.22     37.80                37.0     6.946014        5.407172
# 19500    -121.03     37.67                24.0     7.679251        6.131226
# 14975    -116.99     32.70                15.0     8.205492        6.434547
# 3788     -118.37     34.17                42.0     6.398595        5.147494
# 10991    -117.81     33.73                19.0     8.299783        6.883463
# ...          ...       ...                 ...          ...             ...
# 7012     -118.07     33.96                30.0     6.834109        5.442418
# 20017    -119.06     36.09                11.0     7.852828        6.120297
# 17950    -121.96     37.34                18.0     8.398184        6.845880
# 6387     -118.07     34.16                35.0     8.184793        6.510258
# 15619    -122.42     37.80                50.0     7.822044        6.595781
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 16515    6.257668    5.356586         2.1250          0       1       0
# 19500    7.292337    6.091310         3.1857          0       1       0
# 14975    7.874739    6.418365         4.0444          0       0       0
# 3788     5.934894    5.204007         2.4107          1       0       0
# 10991    7.755767    6.861711         3.0305          1       0       0
# ...           ...         ...            ...        ...     ...     ...
# 7012     6.817831    5.370638         2.6991          1       0       0
# 20017    7.246368    6.030685         3.6786          0       1       0
# 17950    7.550661    6.797940         5.3873          1       0       0
# 6387     7.245655    6.436150         4.1250          0       1       0
# 15619    6.865891    6.569481         3.2356          0       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 16515         0           0       0.778457         1.296724
# 19500         0           0       0.798415         1.260690
# 14975         0           1       0.784176         1.278440
# 3788          0           0       0.804473         1.229552
# 10991         0           0       0.829355         1.209579
# ...         ...         ...            ...              ...
# 7012          0           0       0.796361         1.272495
# 20017         0           0       0.779375         1.302145
# 17950         0           0       0.815162         1.235401
# 6387          0           0       0.795409         1.271691
# 15619         1           0       0.843230         1.190664
#
# [5109 rows x 15 columns]

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.6763161417777643

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest = RandomForestRegressor()

# %%
forest.fit(X_train_s, y_train)

# %%
forest.score(X_test_s, y_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5]
}


grid_search = GridSearchCV(
    estimator=RandomForestRegressor(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

grid_search.fit(X_train_s, y_train)

print("Best Hyperparameters:", grid_search.best_params_)

best_forest = grid_search.best_estimator_

test_score = best_forest.score(X_test_s, y_test)
print(f"Test R² Score with Tuned Model: {test_score:.2f}")
