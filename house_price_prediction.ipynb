# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(["median_house_value"], axis=1)

# %%
y = data["median_house_value"]

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 592      -122.10     37.71                27.0       6740.0          1073.0
# 4348     -118.36     34.11                35.0       3946.0           695.0
# 15943    -122.43     37.72                50.0       2912.0           562.0
# 1114     -121.59     39.78                18.0        945.0           205.0
# 9491     -123.19     39.21                22.0       1542.0           291.0
# ...          ...       ...                 ...          ...             ...
# 9601     -120.48     37.30                49.0       2919.0           719.0
# 16202    -121.28     37.94                44.0       1406.0           357.0
# 18390    -121.87     37.23                19.0       7357.0           963.0
# 19698    -121.62     39.11                11.0       3519.0           577.0
# 15237    -117.26     32.95                22.0       5484.0          1227.0
#
#        population  households  median_income ocean_proximity  \
# 592        2723.0      1035.0         5.2131        NEAR BAY
# 4348       1361.0       620.0         6.5195       <1H OCEAN
# 15943      1989.0       537.0         3.6667        NEAR BAY
# 1114        385.0       207.0         2.1838          INLAND
# 9491        821.0       285.0         3.5917       <1H OCEAN
# ...           ...         ...            ...             ...
# 9601       1956.0       679.0         1.5427          INLAND
# 16202      1489.0       386.0         1.4688          INLAND
# 18390      3018.0       981.0         6.9473       <1H OCEAN
# 19698      1459.0       549.0         4.2792          INLAND
# 15237      1947.0      1012.0         4.4375      NEAR OCEAN
#
#        median_house_value
# 592              252500.0
# 4348             500001.0
# 15943            252600.0
# 1114              58000.0
# 9491             118800.0
# ...                   ...
# 9601              88500.0
# 16202             56800.0
# 18390            361400.0
# 19698            123800.0
# 15237            500001.0
#
# [15324 rows x 10 columns]

# %%
train_data.hist(figsize=(20, 10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924013           -0.107606     0.037371
# latitude            -0.924013  1.000000            0.011987    -0.030937
# housing_median_age  -0.107606  0.011987            1.000000    -0.360403
# total_rooms          0.037371 -0.030937           -0.360403     1.000000
# total_bedrooms       0.058957 -0.059490           -0.320325     0.931284
# population           0.093803 -0.105663           -0.302930     0.862391
# households           0.045982 -0.063984           -0.303918     0.918915
# median_income       -0.011598 -0.082978           -0.126603     0.208499
# median_house_value  -0.037779 -0.151863            0.097118     0.143230
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.058957    0.093803    0.045982      -0.011598
# latitude                 -0.059490   -0.105663   -0.063984      -0.082978
# housing_median_age       -0.320325   -0.302930   -0.303918      -0.126603
# total_rooms               0.931284    0.862391    0.918915       0.208499
# total_bedrooms            1.000000    0.884373    0.979407       0.003712
# population                0.884373    1.000000    0.914000       0.017408
# households                0.979407    0.914000    1.000000       0.024970
# median_income             0.003712    0.017408    0.024970       1.000000
# median_house_value        0.060672   -0.015602    0.074735       0.686760
#
#                     median_house_value
# longitude                    -0.037779
# latitude                     -0.151863
# housing_median_age            0.097118
# total_rooms                   0.143230
# total_bedrooms                0.060672
# population                   -0.015602
# households                    0.074735
# median_income                 0.686760
# median_house_value            1.000000

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data.hist(figsize=(20, 10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data["total_rooms"] = np.log(train_data["total_rooms"] + 1)
train_data["total_bedrooms"] = np.log(train_data["total_bedrooms"] + 1)
train_data["households"] = np.log(train_data["households"] + 1)
train_data["population"] = np.log(train_data["population"] + 1)

# %%
train_data.hist(figsize=(20, 10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6742
# INLAND        4924
# NEAR OCEAN    1946
# NEAR BAY      1708
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity, dtype=int)).drop(["ocean_proximity"], axis=1)

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"] = train_data["total_bedrooms"] / train_data["total_rooms"]
train_data["household_rooms"] = train_data["total_rooms"] / train_data["households"]

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, y_train = train_data.drop(["median_house_value"], axis=1), train_data["median_house_value"]
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9634     -120.89     37.21                25.0       3301.0           678.0
# 7309     -118.19     33.98                34.0       1022.0           286.0
# 17542    -121.88     37.34                44.0       1267.0           353.0
# 6556     -118.11     34.19                50.0       1430.0           186.0
# 6484     -118.02     34.09                24.0       2080.0           514.0
# ...          ...       ...                 ...          ...             ...
# 3896     -118.50     34.21                35.0       1668.0           332.0
# 1525     -122.07     37.89                28.0       3410.0           746.0
# 12948    -121.28     38.63                36.0        120.0            16.0
# 2911     -119.05     35.36                30.0       4635.0           800.0
# 15862    -122.40     37.75                44.0       6848.0          1584.0
#
#        population  households  median_income ocean_proximity  \
# 9634        994.0       306.0         3.2262          INLAND
# 7309       1058.0       275.0         2.6042       <1H OCEAN
# 17542      1018.0       327.0         2.4196       <1H OCEAN
# 6556        620.0       201.0         9.5320          INLAND
# 6484       1976.0       478.0         2.6917          INLAND
# ...           ...         ...            ...             ...
# 3896        807.0       311.0         4.5125       <1H OCEAN
# 1525       1428.0       670.0         4.3864        NEAR BAY
# 12948        30.0        14.0        10.2264          INLAND
# 2911       2307.0       754.0         3.6548          INLAND
# 15862      3269.0      1383.0         2.8679        NEAR BAY
#
#        median_house_value
# 9634              97200.0
# 7309             156700.0
# 17542            194400.0
# 6556             483300.0
# 6484             170000.0
# ...                   ...
# 3896             200300.0
# 1525             266800.0
# 12948            350000.0
# 2911              84700.0
# 15862            243300.0
#
# [5109 rows x 10 columns]

# %%
test_data["total_rooms"] = np.log(test_data["total_rooms"] + 1)
test_data["total_bedrooms"] = np.log(test_data["total_bedrooms"] + 1)
test_data["households"] = np.log(test_data["households"] + 1)
test_data["population"] = np.log(test_data["population"] + 1)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9634     -120.89     37.21                25.0     8.102284        6.520621
# 7309     -118.19     33.98                34.0     6.930495        5.659482
# 17542    -121.88     37.34                44.0     7.145196        5.869297
# 6556     -118.11     34.19                50.0     7.266129        5.231109
# 6484     -118.02     34.09                24.0     7.640604        6.244167
# ...          ...       ...                 ...          ...             ...
# 3896     -118.50     34.21                35.0     7.419980        5.808142
# 1525     -122.07     37.89                28.0     8.134761        6.616065
# 12948    -121.28     38.63                36.0     4.795791        2.833213
# 2911     -119.05     35.36                30.0     8.441607        6.685861
# 15862    -122.40     37.75                44.0     8.831858        7.368340
#
#        population  households  median_income ocean_proximity  \
# 9634     6.902743    5.726848         3.2262          INLAND
# 7309     6.965080    5.620401         2.6042       <1H OCEAN
# 17542    6.926577    5.793014         2.4196       <1H OCEAN
# 6556     6.431331    5.308268         9.5320          INLAND
# 6484     7.589336    6.171701         2.6917          INLAND
# ...           ...         ...            ...             ...
# 3896     6.694562    5.743003         4.5125       <1H OCEAN
# 1525     7.264730    6.508769         4.3864        NEAR BAY
# 12948    3.433987    2.708050        10.2264          INLAND
# 2911     7.744137    6.626718         3.6548          INLAND
# 15862    8.092545    7.232733         2.8679        NEAR BAY
#
#        median_house_value
# 9634              97200.0
# 7309             156700.0
# 17542            194400.0
# 6556             483300.0
# 6484             170000.0
# ...                   ...
# 3896             200300.0
# 1525             266800.0
# 12948            350000.0
# 2911              84700.0
# 15862            243300.0
#
# [5109 rows x 10 columns]

# %%
test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity, dtype=int)).drop(["ocean_proximity"], axis=1)

# %%
test_data["bedroom_ratio"] = test_data["total_bedrooms"] / test_data["total_rooms"]
test_data["household_rooms"] = test_data["total_rooms"] / test_data["households"]

# %%
X_test, y_test = test_data.drop(["median_house_value"], axis=1), test_data["median_house_value"]
X_test_s = scaler.transform(X_test)

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 592      -122.10     37.71                27.0     8.815964        6.979145
# 4348     -118.36     34.11                35.0     8.280711        6.545350
# 15943    -122.43     37.72                50.0     7.976939        6.333280
# 1114     -121.59     39.78                18.0     6.852243        5.327876
# 9491     -123.19     39.21                22.0     7.341484        5.676754
# ...          ...       ...                 ...          ...             ...
# 9601     -120.48     37.30                49.0     7.979339        6.579251
# 16202    -121.28     37.94                44.0     7.249215        5.880533
# 18390    -121.87     37.23                19.0     8.903543        6.871091
# 19698    -121.62     39.11                11.0     8.166216        6.359574
# 15237    -117.26     32.95                22.0     8.609772        7.113142
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 592      7.909857    6.943122         5.2131          0       0       0
# 4348     7.216709    6.431331         6.5195          1       0       0
# 15943    7.595890    6.287859         3.6667          0       0       0
# 1114     5.955837    5.337538         2.1838          0       1       0
# 9491     6.711740    5.655992         3.5917          1       0       0
# ...           ...         ...            ...        ...     ...     ...
# 9601     7.579168    6.522093         1.5427          0       1       0
# 16202    7.306531    5.958425         1.4688          0       1       0
# 18390    8.012681    6.889591         6.9473          1       0       0
# 19698    7.286192    6.309918         4.2792          0       1       0
# 15237    7.574558    6.920672         4.4375          0       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 592           1           0       0.791649         1.269740
# 4348          0           0       0.790433         1.287558
# 15943         1           0       0.793949         1.268626
# 1114          0           0       0.777538         1.283783
# 9491          0           0       0.773243         1.298001
# ...         ...         ...            ...              ...
# 9601          0           0       0.824536         1.223432
# 16202         0           0       0.811196         1.216633
# 18390         0           0       0.771725         1.292318
# 19698         0           0       0.778766         1.294187
# 15237         0           1       0.826171         1.244066
#
# [15324 rows x 15 columns]

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9634     -120.89     37.21                25.0     8.102284        6.520621
# 7309     -118.19     33.98                34.0     6.930495        5.659482
# 17542    -121.88     37.34                44.0     7.145196        5.869297
# 6556     -118.11     34.19                50.0     7.266129        5.231109
# 6484     -118.02     34.09                24.0     7.640604        6.244167
# ...          ...       ...                 ...          ...             ...
# 3896     -118.50     34.21                35.0     7.419980        5.808142
# 1525     -122.07     37.89                28.0     8.134761        6.616065
# 12948    -121.28     38.63                36.0     4.795791        2.833213
# 2911     -119.05     35.36                30.0     8.441607        6.685861
# 15862    -122.40     37.75                44.0     8.831858        7.368340
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 9634     6.902743    5.726848         3.2262          0       1       0
# 7309     6.965080    5.620401         2.6042          1       0       0
# 17542    6.926577    5.793014         2.4196          1       0       0
# 6556     6.431331    5.308268         9.5320          0       1       0
# 6484     7.589336    6.171701         2.6917          0       1       0
# ...           ...         ...            ...        ...     ...     ...
# 3896     6.694562    5.743003         4.5125          1       0       0
# 1525     7.264730    6.508769         4.3864          0       0       0
# 12948    3.433987    2.708050        10.2264          0       1       0
# 2911     7.744137    6.626718         3.6548          0       1       0
# 15862    8.092545    7.232733         2.8679          0       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 9634          0           0       0.804788         1.414789
# 7309          0           0       0.816606         1.233096
# 17542         0           0       0.821433         1.233416
# 6556          0           0       0.719931         1.368832
# 6484          0           0       0.817235         1.238006
# ...         ...         ...            ...              ...
# 3896          0           0       0.782771         1.292003
# 1525          1           0       0.813308         1.249816
# 12948         0           0       0.590771         1.770939
# 2911          0           0       0.792013         1.273875
# 15862         1           0       0.834291         1.221096
#
# [5109 rows x 15 columns]

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.6753298450203544

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest = RandomForestRegressor()

# %%
forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.8276930559680061
